# %% [markdown]
# # ASSIGMENT

# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.

# %% [markdown]
# 1. T-test vs Z-test: Key Differences
# Sample Size:
#
# T-test is typically used when the sample size is small (n < 30).
# Z-test is used when the sample size is large (n ≥ 30).
# Population Standard Deviation:
#
# T-test is used when the population standard deviation is unknown, and the sample standard deviation is used as an estimate.
# Z-test is used when the population standard deviation is known.
# Test Statistic:
#
# The t-test uses the t-distribution, which is broader and accounts for the uncertainty with small samples.
# The z-test uses the normal distribution (Z-distribution), which assumes the data is approximately normally distributed and works best with large sample sizes.
# Distribution Shape:
#
# T-distribution is wider, with heavier tails than the normal distribution, especially with smaller sample sizes.
# Z-distribution is bell-shaped, similar to the normal distribution, and is used when the sample size is large enough for the Central Limit Theorem to apply.
# 2. Example Scenarios
# T-test:
#
# Scenario: A researcher wants to determine if the average height of a group of 20 students is different from the national average height of 170 cm. Since the sample size is small, and the population standard deviation is unknown, the researcher would use a t-test.
# Here, you would use the one-sample t-test to test whether the mean height of the sample is significantly different from the known population mean of 170 cm.
# Z-test:
#
# Scenario: A company wants to test if their new manufacturing process results in a mean time to produce a product that is different from the industry standard of 50 minutes. They have data from a large sample of 1,000 production times, and they know the population standard deviation is 10 minutes.
# In this case, since the sample size is large and the population standard deviation is known, the company would use a z-test (specifically, a one-sample z-test) to determine if the mean production time is significantly different from 50 minutes.

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests.

# %% [markdown]
# One-Tailed vs Two-Tailed Tests: Key Differences
# A one-tailed test and a two-tailed test refer to the direction of the hypothesis test in relation to the critical region where you reject the null hypothesis. They differ in the way the alternative hypothesis is stated and how the critical region is defined.
#
# 1. One-Tailed Test:
# In a one-tailed test, the alternative hypothesis specifies the direction of the effect, i.e., it predicts that the population parameter (like the mean) will either be greater than or less than a certain value.
#
# Null Hypothesis (H₀): The population parameter is equal to the hypothesized value.
#
# Example:
# 𝐻
# 0
# :
# 𝜇
# =
# 𝜇
# 0
# H
# 0
# ​
#  :μ=μ
# 0
# ​
#
# Alternative Hypothesis (H₁): The population parameter is either greater than or less than the hypothesized value (depending on the direction of the test).
#
# Example:
# 𝐻
# 1
# :
# 𝜇
# >
# 𝜇
# 0
# H
# 1
# ​
#  :μ>μ
# 0
# ​
#   (Right-tailed test) or
# 𝐻
# 1
# :
# 𝜇
# <
# 𝜇
# 0
# H
# 1
# ​
#  :μ<μ
# 0
# ​
#   (Left-tailed test)
# Critical Region: The critical region (where we reject the null hypothesis) is entirely on one side of the distribution.
#
# In a right-tailed test, the critical region is in the right tail (for values greater than the hypothesized value).
# In a left-tailed test, the critical region is in the left tail (for values less than the hypothesized value).
# Example Scenario:
#
# You are testing whether a new drug improves the recovery time from an illness. The hypothesis is that the recovery time with the new drug is shorter than the average recovery time of 14 days. Since you are only interested in the drug making recovery time shorter, you would use a left-tailed test.
# Usage: One-tailed tests are typically used when the researcher has a clear direction of expectation and is only interested in whether the effect is in one direction (greater or smaller).
#
# 2. Two-Tailed Test:
# In a two-tailed test, the alternative hypothesis does not specify the direction of the effect. It just states that the population parameter is different from the hypothesized value, without indicating whether it is greater or smaller.
#
# Null Hypothesis (H₀): The population parameter is equal to the hypothesized value.
#
# Example:
# 𝐻
# 0
# :
# 𝜇
# =
# 𝜇
# 0
# H
# 0
# ​
#  :μ=μ
# 0
# ​
#
# Alternative Hypothesis (H₁): The population parameter is different from the hypothesized value (either greater or smaller).
#
# Example:
# 𝐻
# 1
# :
# 𝜇
# ≠
# 𝜇
# 0
# H
# 1
# ​
#  :μ
# 
# =μ
# 0
# ​
#
# Critical Region: The critical region is divided into two equal parts, one on the left tail and one on the right tail of the distribution.
#
# You reject the null hypothesis if the test statistic falls into either the lower or upper tail of the distribution.
# Example Scenario:
#
# You want to test if a coin is biased, and you hypothesize that the probability of landing heads is different from 0.5. In this case, you are testing for a difference in either direction (it could be biased towards heads or tails). A two-tailed test is appropriate because you are not interested in the direction of the bias, just that it is different from 0.5.
# Usage: Two-tailed tests are used when the researcher is interested in any significant deviation (either an increase or decrease) from the hypothesized value, without assuming a specific direction.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.

# %% [markdown]
# Type 1 Error
# A Type 1 error occurs when the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is true, but we incorrectly reject it. This is also known as a false positive.
#
# Example Scenario: A pharmaceutical company tests a new drug to determine if it lowers blood pressure. The null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is that the drug has no effect. A Type 1 error would occur if the researchers conclude that the drug is effective when, in reality, it is not.
#
# Consequence: Approving an ineffective drug could lead to wasted resources and potential health risks.
#
# Type 2 Error
# A Type 2 error occurs when the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is false, but we fail to reject it. This is also known as a false negative.
#
# Example Scenario: The same pharmaceutical company tests another drug for lowering blood pressure. The null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is that the drug has no effect. A Type 2 error would occur if the researchers conclude that the drug is not effective when, in reality, it is effective.
#
# Consequence: Missing the opportunity to market a beneficial drug could lead to lost profits and prevent patients from receiving effective treatment.

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.

# %% [markdown]
# Bayes's Theorem is a mathematical formula used to update the probability of a hypothesis based on new evidence. It describes the relationship between conditional probabilities and is given by the formula:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B): The probability of event
# 𝐴
# A given that
# 𝐵
# B has occurred (posterior probability).
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A): The probability of event
# 𝐵
# B given that
# 𝐴
# A has occurred (likelihood).
# 𝑃
# (
# 𝐴
# )
# P(A): The prior probability of event
# 𝐴
# A.
# 𝑃
# (
# 𝐵
# )
# P(B): The total probability of event
# 𝐵
# B, calculated as:
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# ¬
# 𝐴
# )
# ⋅
# 𝑃
# (
# ¬
# 𝐴
# )
# P(B)=P(B∣A)⋅P(A)+P(B∣¬A)⋅P(¬A)
# Example: Medical Diagnosis
# Scenario:
# A doctor is testing a patient for a rare disease that affects 1% of the population (
# 𝑃
# (
# 𝐷
# )
# =
# 0.01
# P(D)=0.01). The test is 95% accurate, meaning:
#
# If the patient has the disease (
# 𝐷
# D), the test gives a positive result (
# 𝑇
# T) 95% of the time (
# 𝑃
# (
# 𝑇
# ∣
# 𝐷
# )
# =
# 0.95
# P(T∣D)=0.95).
# If the patient does not have the disease (
# ¬
# 𝐷
# ¬D), the test gives a positive result 5% of the time (
# 𝑃
# (
# 𝑇
# ∣
# ¬
# 𝐷
# )
# =
# 0.05
# P(T∣¬D)=0.05).

# %% [markdown]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

# %% [markdown]
# What is a Confidence Interval (CI)?
# A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (e.g., mean or proportion) with a specified level of confidence. It reflects the uncertainty or variability inherent in sample-based estimates.
#
# The confidence level (e.g., 95%) indicates the proportion of times the CI would contain the true parameter if repeated sampling were performed.
# A higher confidence level results in a wider interval, while a lower confidence level results in a narrower interval.
# How to Calculate a Confidence Interval?
# For a population mean (
# 𝜇
# μ) with a known or large sample size, the confidence interval is calculated as:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z⋅
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#  : Sample mean
# 𝑍
# Z: Z-score corresponding to the confidence level (e.g., 1.96 for 95%)
# 𝜎
# σ: Population standard deviation (or sample standard deviation for large
# 𝑛
# n)
# 𝑛
# n: Sample size
# Example: Calculating a Confidence Interval
# Scenario:
# A sample of 50 students has an average test score of 75, with a standard deviation of 10. Calculate the 95% confidence interval for the population mean.
#
# Solution:
# Identify the components:
#
# Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 75
# Standard deviation (
# 𝜎
# σ) = 10
# Sample size (
# 𝑛
# n) = 50
# Z-score for 95% confidence = 1.96
# Calculate the standard error (SE):
#
# 𝑆
# 𝐸
# =
# 𝜎
# 𝑛
# =
# 10
# 50
# =
# 10
# 7.071
# ≈
# 1.414
# SE=
# n
# ​
#
# σ
# ​
#  =
# 50
# ​
#
# 10
# ​
#  =
# 7.071
# 10
# ​
#  ≈1.414
# Determine the margin of error (ME):
#
# 𝑀
# 𝐸
# =
# 𝑍
# ⋅
# 𝑆
# 𝐸
# =
# 1.96
# ⋅
# 1.414
# ≈
# 2.77
# ME=Z⋅SE=1.96⋅1.414≈2.77
# Calculate the confidence interval:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑀
# 𝐸
# =
# 75
# ±
# 2.77
# CI=
# x
# ˉ
#  ±ME=75±2.77
# 𝐶
# 𝐼
# =
# (
# 75
# −
# 2.77
# ,
# 75
# +
# 2.77
# )
# =
# (
# 72.23
# ,
# 77.77
# )
# CI=(75−2.77,75+2.77)=(72.23,77.77)
# Interpretation:
# We are 95% confident that the true population mean test score lies between 72.23 and 77.77.

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.

# %% [markdown]
# Using Bayes' Theorem
# Bayes' Theorem helps calculate the updated probability of an event occurring (
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B)) given:
#
# Prior knowledge of the event's probability (
# 𝑃
# (
# 𝐴
# )
# P(A)),
# Probability of related evidence (
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A)),
# And the overall probability of the evidence (
# 𝑃
# (
# 𝐵
# )
# P(B)).
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# ¬
# 𝐴
# )
# ⋅
# 𝑃
# (
# ¬
# 𝐴
# )
# P(B)=P(B∣A)⋅P(A)+P(B∣¬A)⋅P(¬A)
#
# Sample Problem: Spam Email Detection
# Problem:
# An email filter is designed to detect spam. The following probabilities are known:
#
# The probability that any given email is spam (
# 𝑃
# (
# 𝑆
# )
# P(S)) = 0.2.
# The probability that a spam email contains the word "free" (
# 𝑃
# (
# 𝐹
# ∣
# 𝑆
# )
# P(F∣S)) = 0.7.
# The probability that a non-spam email contains the word "free" (
# 𝑃
# (
# 𝐹
# ∣
# ¬
# 𝑆
# )
# P(F∣¬S)) = 0.1.
# If an email contains the word "free," what is the probability that it is spam (
# 𝑃
# (
# 𝑆
# ∣
# 𝐹
# )
# P(S∣F))?
#
# Solution:
# Identify the known probabilities:
#
# 𝑃
# (
# 𝑆
# )
# =
# 0.2
# P(S)=0.2
# 𝑃
# (
# ¬
# 𝑆
# )
# =
# 1
# −
# 𝑃
# (
# 𝑆
# )
# =
# 0.8
# P(¬S)=1−P(S)=0.8
# 𝑃
# (
# 𝐹
# ∣
# 𝑆
# )
# =
# 0.7
# P(F∣S)=0.7
# 𝑃
# (
# 𝐹
# ∣
# ¬
# 𝑆
# )
# =
# 0.1
# P(F∣¬S)=0.1
# Calculate
# 𝑃
# (
# 𝐹
# )
# P(F): Using the law of total probability:
#
# 𝑃
# (
# 𝐹
# )
# =
# 𝑃
# (
# 𝐹
# ∣
# 𝑆
# )
# ⋅
# 𝑃
# (
# 𝑆
# )
# +
# 𝑃
# (
# 𝐹
# ∣
# ¬
# 𝑆
# )
# ⋅
# 𝑃
# (
# ¬
# 𝑆
# )
# P(F)=P(F∣S)⋅P(S)+P(F∣¬S)⋅P(¬S)
# 𝑃
# (
# 𝐹
# )
# =
# (
# 0.7
# ⋅
# 0.2
# )
# +
# (
# 0.1
# ⋅
# 0.8
# )
# P(F)=(0.7⋅0.2)+(0.1⋅0.8)
# 𝑃
# (
# 𝐹
# )
# =
# 0.14
# +
# 0.08
# =
# 0.22
# P(F)=0.14+0.08=0.22
# Apply Bayes' Theorem:
#
# 𝑃
# (
# 𝑆
# ∣
# 𝐹
# )
# =
# 𝑃
# (
# 𝐹
# ∣
# 𝑆
# )
# ⋅
# 𝑃
# (
# 𝑆
# )
# 𝑃
# (
# 𝐹
# )
# P(S∣F)=
# P(F)
# P(F∣S)⋅P(S)
# ​
#
# 𝑃
# (
# 𝑆
# ∣
# 𝐹
# )
# =
# 0.7
# ⋅
# 0.2
# 0.22
# P(S∣F)=
# 0.22
# 0.7⋅0.2
# ​
#
# 𝑃
# (
# 𝑆
# ∣
# 𝐹
# )
# =
# 0.14
# 0.22
# ≈
# 0.636
# P(S∣F)=
# 0.22
# 0.14
# ​
#  ≈0.636
# Final Answer:
# If an email contains the word "free," the probability that it is spam is approximately 63.6%.
#
# Key Takeaways:
# Bayes' Theorem integrates prior knowledge (
# 𝑃
# (
# 𝑆
# )
# P(S)) and new evidence (
# 𝑃
# (
# 𝐹
# ∣
# 𝑆
# )
# P(F∣S)) to compute the posterior probability (
# 𝑃
# (
# 𝑆
# ∣
# 𝐹
# )
# P(S∣F)).

# %% [markdown]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.

# %% [markdown]
# Problem Statement
# We are tasked with calculating a 95% confidence interval (CI) for a sample with:
#
# Mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 50
# Standard deviation (
# 𝑠
# s) = 5
# Sample size (
# 𝑛
# n) = Not explicitly given. Assuming
# 𝑛
# =
# 30
# n=30 for this calculation (large enough for normal approximation).
# Formula for Confidence Interval
# The confidence interval for the mean is calculated as:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# ⋅
# 𝑠
# 𝑛
# CI=
# x
# ˉ
#  ±Z⋅
# n
# ​
#
# s
# ​
#
# Where:
#
# 𝑍
# Z: Z-score corresponding to the confidence level (for 95%,
# 𝑍
# =
# 1.96
# Z=1.96)
# 𝑠
# s: Sample standard deviation
# 𝑛
# n: Sample size
# 𝑠
# 𝑛
# n
# ​
#
# s
# ​
#  : Standard error (SE)
# Solution
# Calculate the Standard Error (SE):
# 𝑆
# 𝐸
# =
# 𝑠
# 𝑛
# =
# 5
# 30
# =
# 5
# 5.477
# ≈
# 0.913
# SE=
# n
# ​
#
# s
# ​
#  =
# 30
# ​
#
# 5
# ​
#  =
# 5.477
# 5
# ​
#  ≈0.913
# Determine the Margin of Error (ME):
# 𝑀
# 𝐸
# =
# 𝑍
# ⋅
# 𝑆
# 𝐸
# =
# 1.96
# ⋅
# 0.913
# ≈
# 1.79
# ME=Z⋅SE=1.96⋅0.913≈1.79
# Calculate the Confidence Interval:
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑀
# 𝐸
# =
# 50
# ±
# 1.79
# CI=
# x
# ˉ
#  ±ME=50±1.79
# 𝐶
# 𝐼
# =
# (
# 50
# −
# 1.79
# ,
# 50
# +
# 1.79
# )
# =
# (
# 48.21
# ,
# 51.79
# )
# CI=(50−1.79,50+1.79)=(48.21,51.79)
# Interpretation
# We are 95% confident that the true population mean lies between 48.21 and 51.79. This means that if we were to repeat this sampling process many times, approximately 95% of the intervals would contain the true population mean.

# %% [markdown]
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.

# %% [markdown]
# What is the Margin of Error in a Confidence Interval?
# The margin of error (ME) is the range of uncertainty around a sample statistic, such as a mean or proportion. It quantifies how much the sample estimate is expected to differ from the true population parameter due to random sampling variability. The margin of error is part of the confidence interval formula:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑀
# 𝐸
# CI=
# x
# ˉ
#  ±ME
# For a confidence interval for the mean, the margin of error is calculated as:
#
# 𝑀
# 𝐸
# =
# 𝑍
# ⋅
# 𝜎
# 𝑛
# ME=Z⋅
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑍
# Z: Z-score corresponding to the confidence level (e.g., 1.96 for 95% confidence).
# 𝜎
# σ: Population standard deviation (or
# 𝑠
# s, the sample standard deviation).
# 𝑛
# n: Sample size.
# How Does Sample Size Affect the Margin of Error?
# The sample size (
# 𝑛
# n) is in the denominator of the formula for the standard error (
# 𝜎
# 𝑛
# n
# ​
#
# σ
# ​
#  ).
# As the sample size increases, the standard error decreases because
# 𝑛
# n
# ​
#   increases.
# A smaller standard error reduces the margin of error, resulting in a narrower confidence interval and a more precise estimate.
# Key Relationship:
# 𝑀
# 𝐸
# ∝
# 1
# 𝑛
# ME∝
# n
# ​
#
# 1
# ​
#
# The margin of error decreases with the square root of the sample size. Doubling the sample size reduces the margin of error by approximately
# 1
# /
# 2
# ≈
# 70.7
# %
# 1/
# 2
# ​
#  ≈70.7%.
#
# Example Scenario:
# Problem:
# A poll is conducted to estimate the proportion of voters who support a policy. With a sample size of 100 voters, the margin of error is calculated to be 5%.
#
# Scenario with Larger Sample:
# If the sample size is increased to 400 voters, the margin of error would be:
#
# 𝑀
# 𝐸
# new
# =
# 𝑀
# 𝐸
# original
# ⋅
# 𝑛
# original
# 𝑛
# new
# ME
# new
# ​
#  =ME
# original
# ​
#  ⋅
# n
# new
# ​
#
# n
# original
# ​
#
# ​
#
# ​
#
# 𝑀
# 𝐸
# new
# =
# 5
# %
# ⋅
# 100
# 400
# ME
# new
# ​
#  =5%⋅
# 400
# 100
# ​
#
# ​
#
# 𝑀
# 𝐸
# new
# =
# 5
# %
# ⋅
# 1
# 2
# =
# 2.5
# %
# ME
# new
# ​
#  =5%⋅
# 2
# 1
# ​
#  =2.5%
# Explanation:
# By increasing the sample size from 100 to 400, the margin of error is halved, providing a more precise estimate of voter support.
#
# Real-World Example:
# In medical trials, researchers test the effectiveness of a new drug. With a small sample of 20 patients, the confidence interval for the drug's effectiveness might be wide due to a large margin of error. By increasing the sample size to 200 patients, the margin of error decreases, leading to a narrower confidence interval and greater confidence in the results.
#
# Summary:
# The margin of error quantifies the precision of an estimate.
# A larger sample size reduces the margin of error, improving the accuracy of the estimate.
# The relationship is inverse and proportional to the square root of the sample size.

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.

# %% [markdown]
# What is a Z-Score?
# A z-score indicates how many standard deviations a data point is from the population mean. It is calculated using the formula:
#
# 𝑧
# =
# 𝑥
# −
# 𝜇
# 𝜎
# z=
# σ
# x−μ
# ​
#
# Where:
#
# 𝑥
# x: The data point
# 𝜇
# μ: The population mean
# 𝜎
# σ: The population standard deviation
# Given:
# Data point (
# 𝑥
# x) = 75
# Population mean (
# 𝜇
# μ) = 70
# Population standard deviation (
# 𝜎
# σ) = 5
# Calculate the Z-Score:
# 𝑧
# =
# 𝑥
# −
# 𝜇
# 𝜎
# =
# 75
# −
# 70
# 5
# =
# 5
# 5
# =
# 1
# z=
# σ
# x−μ
# ​
#  =
# 5
# 75−70
# ​
#  =
# 5
# 5
# ​
#  =1
# Interpretation:
# A z-score of 1 means that the data point (75) is 1 standard deviation above the mean.
#
# In a standard normal distribution:
# Approximately 68% of data points lie within 1 standard deviation (
# −
# 1
# ≤
# 𝑧
# ≤
# 1
# −1≤z≤1).
# This means the value of 75 is above the average, but within the typical range of variation for most data points in the distribution.
# Key Insights:
# Z-scores allow comparison of data points across different distributions.
# Positive z-scores indicate values above the mean, and negative z-scores indicate values below the mean.
# Larger absolute z-scores indicate that the data point is farther from the mean.

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.

# %% [markdown]
# Hypothesis Test for the Effectiveness of a Weight Loss Drug
# We will use a one-sample t-test to determine whether the drug is significantly effective. The test checks if the sample mean weight loss (
# 𝑥
# ˉ
# x
# ˉ
#  ) is significantly different from 0 (no weight loss).
#
# Step 1: Formulate Hypotheses
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): The drug has no effect on weight loss, i.e.,
# 𝜇
# =
# 0
# μ=0.
# Alternative Hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  ): The drug is effective, i.e.,
# 𝜇
# >
# 0
# μ>0.
# This is a one-tailed test because we are only interested in testing whether the drug leads to weight loss (
# 𝜇
# >
# 0
# μ>0).
#
# Step 2: Identify the Test Statistic
# The t-test statistic is calculated as:
#
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# 𝑛
# t=
# n
# ​
#
# s
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where:
#
# 𝑥
# ˉ
# =
# 6
# x
# ˉ
#  =6: Sample mean
# 𝜇
# 0
# =
# 0
# μ
# 0
# ​
#  =0: Hypothesized population mean
# 𝑠
# =
# 2.5
# s=2.5: Sample standard deviation
# 𝑛
# =
# 50
# n=50: Sample size
# Step 3: Perform the Calculation
# Calculate the Standard Error (SE):
# 𝑆
# 𝐸
# =
# 𝑠
# 𝑛
# =
# 2.5
# 50
# =
# 2.5
# 7.071
# ≈
# 0.3536
# SE=
# n
# ​
#
# s
# ​
#  =
# 50
# ​
#
# 2.5
# ​
#  =
# 7.071
# 2.5
# ​
#  ≈0.3536
# Calculate the t-Statistic:
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑆
# 𝐸
# =
# 6
# −
# 0
# 0.3536
# ≈
# 16.98
# t=
# SE
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#  =
# 0.3536
# 6−0
# ​
#  ≈16.98
# Step 4: Determine the Critical Value
# For a one-tailed t-test at a 95% confidence level with
# 𝑛
# −
# 1
# =
# 49
# n−1=49 degrees of freedom:
#
# Using a t-table or calculator, the critical value (
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# t
# crit
# ​
#  ) for
# 𝑑
# 𝑓
# =
# 49
# df=49 at
# 𝛼
# =
# 0.05
# α=0.05 is approximately 1.676.
# Step 5: Compare t-Statistic with Critical Value
# 𝑡
# =
# 16.98
# t=16.98
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# =
# 1.676
# t
# crit
# ​
#  =1.676
# Since
# 𝑡
# >
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# t>t
# crit
# ​
#  , we reject the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ).
#
# Step 6: Conclusion
# At the 95% confidence level, there is sufficient evidence to conclude that the new weight loss drug is significantly effective. The average weight loss of 6 pounds is highly unlikely to have occurred by chance.
#
# Key Insights:
# The extremely large t-value (
# 𝑡
# =
# 16.98
# t=16.98

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.

# %% [markdown]
# Problem Statement
# We need to calculate the 95% confidence interval (CI) for the proportion of people satisfied with their job.
#
# Given Data
# Sample size (
# 𝑛
# n) = 500
# Sample proportion (
# 𝑝
# ^
# p
# ^
# ​
#  ) = 65% = 0.65
# Confidence level = 95% (
# 𝑍
# =
# 1.96
# Z=1.96 for a 95% CI)
# Formula for Confidence Interval of Proportion
# 𝐶
# 𝐼
# =
# 𝑝
# ^
# ±
# 𝑍
# ⋅
# 𝑝
# ^
# (
# 1
# −
# 𝑝
# ^
# )
# 𝑛
# CI=
# p
# ^
# ​
#  ±Z⋅
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# Where:
#
# 𝑝
# ^
# p
# ^
# ​
#  : Sample proportion
# 𝑛
# n: Sample size
# 𝑍
# Z: Z-score for the confidence level
# Step 1: Calculate the Standard Error (SE)
# 𝑆
# 𝐸
# =
# 𝑝
# ^
# (
# 1
# −
# 𝑝
# ^
# )
# 𝑛
# SE=
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# 𝑆
# 𝐸
# =
# 0.65
# ⋅
# (
# 1
# −
# 0.65
# )
# 500
# =
# 0.65
# ⋅
# 0.35
# 500
# =
# 0.2275
# 500
# =
# 0.000455
# ≈
# 0.0213
# SE=
# 500
# 0.65⋅(1−0.65)
# ​
#
# ​
#  =
# 500
# 0.65⋅0.35
# ​
#
# ​
#  =
# 500
# 0.2275
# ​
#
# ​
#  =
# 0.000455
# ​
#  ≈0.0213
# Step 2: Calculate the Margin of Error (ME)
# 𝑀
# 𝐸
# =
# 𝑍
# ⋅
# 𝑆
# 𝐸
# =
# 1.96
# ⋅
# 0.0213
# ≈
# 0.0417
# ME=Z⋅SE=1.96⋅0.0213≈0.0417
# Step 3: Calculate the Confidence Interval
# 𝐶
# 𝐼
# =
# 𝑝
# ^
# ±
# 𝑀
# 𝐸
# =
# 0.65
# ±
# 0.0417
# CI=
# p
# ^
# ​
#  ±ME=0.65±0.0417
# 𝐶
# 𝐼
# =
# (
# 0.65
# −
# 0.0417
# ,
# 0.65
# +
# 0.0417
# )
# =
# (
# 0.6083
# ,
# 0.6917
# )
# CI=(0.65−0.0417,0.65+0.0417)=(0.6083,0.6917)
# Final Answer
# The 95% confidence interval for the true proportion of people satisfied with their job is approximately:
#
# (
# 60.83
# %
# ,
# 69.17
# %
# )
# (60.83%,69.17%)
# Interpretation
# We are 95% confident that the true proportion of people satisfied with their job lies between 60.83% and 69.17%. This means that if we were to repeat the survey many times, approximately 95% of the calculated intervals would contain the true proportion.

# %% [markdown]
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.

# %% [markdown]
# Hypothesis Testing for Two Teaching Methods
# We will conduct a two-sample t-test to determine if there is a significant difference in mean scores between the two teaching methods at a significance level of
# 𝛼
# =
# 0.01
# α=0.01.
#
# Step 1: Define the Hypotheses
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): There is no difference in mean scores, i.e.,
# 𝜇
# 𝐴
# =
# 𝜇
# 𝐵
# μ
# A
# ​
#  =μ
# B
# ​
#  .
# Alternative Hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  ): There is a significant difference in mean scores, i.e.,
# 𝜇
# 𝐴
# ≠
# 𝜇
# 𝐵
# μ
# A
# ​
#
# 
# =μ
# B
# ​
#  .
# This is a two-tailed test because we are testing for any difference (not just greater or less).
#
# Step 2: Given Data
# Sample A:
# Mean (
# 𝑥
# ˉ
# 𝐴
# x
# ˉ
#
# A
# ​
#  ) = 85
# Standard deviation (
# 𝑠
# 𝐴
# s
# A
# ​
#  ) = 6
# Sample size (
# 𝑛
# 𝐴
# n
# A
# ​
#  ) = Assume
# 𝑛
# 𝐴
# =
# 30
# n
# A
# ​
#  =30
# Sample B:
# Mean (
# 𝑥
# ˉ
# 𝐵
# x
# ˉ
#
# B
# ​
#  ) = 82
# Standard deviation (
# 𝑠
# 𝐵
# s
# B
# ​
#  ) = 5
# Sample size (
# 𝑛
# 𝐵
# n
# B
# ​
#  ) = Assume
# 𝑛
# 𝐵
# =
# 30
# n
# B
# ​
#  =30
# Significance level (
# 𝛼
# α) = 0.01
# Step 3: Calculate the Test Statistic
# The formula for the t-test statistic for two independent samples is:
#
# 𝑡
# =
# 𝑥
# ˉ
# 𝐴
# −
# 𝑥
# ˉ
# 𝐵
# 𝑠
# 𝐴
# 2
# 𝑛
# 𝐴
# +
# 𝑠
# 𝐵
# 2
# 𝑛
# 𝐵
# t=
# n
# A
# ​
#
# s
# A
# 2
# ​
#
# ​
#  +
# n
# B
# ​
#
# s
# B
# 2
# ​
#
# ​
#
# ​
#
# x
# ˉ
#
# A
# ​
#  −
# x
# ˉ
#
# B
# ​
#
# ​
#
# Step 3.1: Compute the standard error:
# 𝑆
# 𝐸
# =
# 𝑠
# 𝐴
# 2
# 𝑛
# 𝐴
# +
# 𝑠
# 𝐵
# 2
# 𝑛
# 𝐵
# SE=
# n
# A
# ​
#
# s
# A
# 2
# ​
#
# ​
#  +
# n
# B
# ​
#
# s
# B
# 2
# ​
#
# ​
#
# ​
#
# 𝑆
# 𝐸
# =
# 6
# 2
# 30
# +
# 5
# 2
# 30
# =
# 36
# 30
# +
# 25
# 30
# =
# 61
# 30
# ≈
# 2.033
# ≈
# 1.426
# SE=
# 30
# 6
# 2
#
# ​
#  +
# 30
# 5
# 2
#
# ​
#
# ​
#  =
# 30
# 36
# ​
#  +
# 30
# 25
# ​
#
# ​
#  =
# 30
# 61
# ​
#
# ​
#  ≈
# 2.033
# ​
#  ≈1.426
# Step 3.2: Compute the t-statistic:
# 𝑡
# =
# 𝑥
# ˉ
# 𝐴
# −
# 𝑥
# ˉ
# 𝐵
# 𝑆
# 𝐸
# =
# 85
# −
# 82
# 1.426
# ≈
# 3
# 1.426
# ≈
# 2.104
# t=
# SE
# x
# ˉ
#
# A
# ​
#  −
# x
# ˉ
#
# B
# ​
#
# ​
#  =
# 1.426
# 85−82
# ​
#  ≈
# 1.426
# 3
# ​
#  ≈2.104
# Step 4: Determine the Critical Value
# For a two-tailed test with
# 𝑑
# 𝑓
# =
# 𝑛
# 𝐴
# +
# 𝑛
# 𝐵
# −
# 2
# =
# 30
# +
# 30
# −
# 2
# =
# 58
# df=n
# A
# ​
#  +n
# B
# ​
#  −2=30+30−2=58 and
# 𝛼
# =
# 0.01
# α=0.01:
#
# Using a t-table or calculator, the critical value (
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# t
# crit
# ​
#  ) for
# 𝑑
# 𝑓
# =
# 58
# df=58 at
# 𝛼
# =
# 0.01
# α=0.01 (two-tailed) is approximately 2.660.
# Step 5: Compare t-Statistic with Critical Value
# 𝑡
# =
# 2.104
# t=2.104
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# =
# 2.660
# t
# crit
# ​
#  =2.660
# Since
# 𝑡
# <
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# t<t
# crit
# ​
#  , we fail to reject the null hypothesis.
#
# Step 6: Conclusion
# At the 0.01 significance level, there is insufficient evidence to conclude that the two teaching methods lead to significantly different student performance. The observed difference in mean scores (85 vs. 82) could be due to random variation rather than a true effect of the teaching methods.
#
# Key Insights:
# The calculated t-statistic (
# 2.104
# 2.104) does not exceed the critical value (
# 2.660
# 2.660), indicating no statistically significant difference.
# A larger sample size might provide more power to detect smaller differences.

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.

# %% [markdown]
# Problem Statement:
# We are tasked with calculating the 90% confidence interval (CI) for the population mean based on a sample of 50 observations with:
#
# Population mean (
# 𝜇
# μ) = 60
# Population standard deviation (
# 𝜎
# σ) = 8
# Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 65
# Sample size (
# 𝑛
# n) = 50
# Confidence level = 90%
# Formula for Confidence Interval for a Population Mean
# The formula is:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z⋅
# n
# ​
#
# σ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = Sample mean = 65
# 𝜎
# σ = Population standard deviation = 8
# 𝑛
# n = Sample size = 50
# 𝑍
# Z = Z-score for 90% confidence level = 1.645 (from Z-tables)
# Step 1: Calculate the Standard Error (SE)
# 𝑆
# 𝐸
# =
# 𝜎
# 𝑛
# =
# 8
# 50
# =
# 8
# 7.071
# ≈
# 1.128
# SE=
# n
# ​
#
# σ
# ​
#  =
# 50
# ​
#
# 8
# ​
#  =
# 7.071
# 8
# ​
#  ≈1.128
# Step 2: Calculate the Margin of Error (ME)
# 𝑀
# 𝐸
# =
# 𝑍
# ⋅
# 𝑆
# 𝐸
# =
# 1.645
# ⋅
# 1.128
# ≈
# 1.860
# ME=Z⋅SE=1.645⋅1.128≈1.860
# Step 3: Calculate the Confidence Interval
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑀
# 𝐸
# =
# 65
# ±
# 1.860
# CI=
# x
# ˉ
#  ±ME=65±1.860
# 𝐶
# 𝐼
# =
# (
# 65
# −
# 1.860
# ,
# 65
# +
# 1.860
# )
# =
# (
# 63.14
# ,
# 66.86
# )
# CI=(65−1.860,65+1.860)=(63.14,66.86)
# Final Answer:
# The 90% confidence interval for the true population mean is approximately:
#
# (
# 63.14
# ,
# 66.86
# )
# (63.14,66.86)
# Interpretation:
# We are 90% confident that the true population mean lies between 63.14 and 66.86. This means that if we were to repeatedly take samples and calculate confidence intervals, about 90% of those intervals would contain the true population mean.

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [markdown]
# Hypothesis Testing for the Effects of Caffeine on Reaction Time
# We are tasked with conducting a one-sample t-test to determine if caffeine has a significant effect on reaction time. The significance level is set at 0.10 (90% confidence level).
#
# Step 1: Define the Hypotheses
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): Caffeine has no effect on reaction time, i.e.,
# 𝜇
# =
# 0.25
# μ=0.25.
# Alternative Hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  ): Caffeine has an effect on reaction time, i.e.,
# 𝜇
# ≠
# 0.25
# μ
# 
# =0.25 (two-tailed test).
# Step 2: Given Data
# Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 0.25 seconds
# Population standard deviation (
# 𝜎
# σ) = 0.05 seconds
# Sample size (
# 𝑛
# n) = 30
# Confidence level = 90% (two-tailed test with
# 𝛼
# =
# 0.10
# α=0.10)
# Degrees of freedom (
# 𝑑
# 𝑓
# df) = 29 (since
# 𝑛
# −
# 1
# =
# 30
# −
# 1
# n−1=30−1)
# Step 3: Calculate the t-Statistic
# The formula for the t-statistic is:
#
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# 𝑛
# t=
# n
# ​
#
# s
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = 0.25
# 𝜇
# 0
# μ
# 0
# ​
#   = 0.25 (hypothesized population mean)
# 𝑠
# s = 0.05 (standard deviation)
# 𝑛
# n = 30 (sample size)
# Standard Error (SE):
# 𝑆
# 𝐸
# =
# 𝑠
# 𝑛
# =
# 0.05
# 30
# =
# 0.05
# 5.477
# ≈
# 0.0091
# SE=
# n
# ​
#
# s
# ​
#  =
# 30
# ​
#
# 0.05
# ​
#  =
# 5.477
# 0.05
# ​
#  ≈0.0091
# t-Statistic:
# 𝑡
# =
# 0.25
# −
# 0.25
# 0.0091
# =
# 0
# 0.0091
# =
# 0
# t=
# 0.0091
# 0.25−0.25
# ​
#  =
# 0.0091
# 0
# ​
#  =0
# Step 4: Determine the Critical Value
# For a two-tailed test at 90% confidence level and
# 𝑑
# 𝑓
# =
# 29
# df=29:
#
# Using a t-table or calculator, the critical value (
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# t
# crit
# ​
#  ) is approximately 1.699.
# Step 5: Compare t-Statistic with Critical Value
# Calculated
# 𝑡
# =
# 0
# t=0
# Critical
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# =
# 1.699
# t
# crit
# ​
#  =1.699
# Since
# 𝑡
# =
# 0
# t=0 is less than the critical value of 1.699, we fail to reject the null hypothesis.
#
# Step 6: Conclusion
# At the 90% confidence level, there is insufficient evidence to conclude that caffeine has a significant effect on reaction time. The observed sample mean (0.25 seconds) is not far enough from the hypothesized mean to reject the null hypothesis.
